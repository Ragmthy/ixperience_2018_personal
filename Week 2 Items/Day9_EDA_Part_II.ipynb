# %% [markdown]
# # Day 9, Exploratory Data Analysis Part II

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image

# %%
# %matplotlib inline

plt.rcParams['figure.figsize'] = (10,10)

# %%
bnbs = pd.read_csv("data/airbnb_new_cols.csv")
bnbs.head()
# Out:
#    room_id  host_id        room_type       neighborhood  reviews  \
# 0     6499    14455  Entire home/apt              Belém        8
# 1    17031    66015  Entire home/apt           Alvalade        0
# 2    25659   107347  Entire home/apt  Santa Maria Maior       63
# 3    29248   125768  Entire home/apt  Santa Maria Maior      225
# 4    29396   126415  Entire home/apt  Santa Maria Maior      132
#
#    overall_satisfaction  accommodates  bedrooms  price  \
# 0                   5.0             2         1     57
# 1                   0.0             2         1     46
# 2                   5.0             3         1     69
# 3                   4.5             4         1     58
# 4                   5.0             4         1     67
#
#          relative_reviews price_ratings
# 0    Few have Bnb-ed here             $
# 1    Few have Bnb-ed here             $
# 2    Few have Bnb-ed here             $
# 3  Loads have Bnb-ed here             $
# 4   Many have Bnb-ed here             $

# %%
bnbs.dtypes
# Out:
# room_id                   int64
# host_id                   int64
# room_type                object
# neighborhood             object
# reviews                   int64
# overall_satisfaction    float64
# accommodates              int64
# bedrooms                  int64
# price                     int64
# relative_reviews         object
# price_ratings            object
# dtype: object

# %%
#Function to make all the numerical variable's into visual graphs

def numerical_variable_distribution(df, col):
    #df[col].plot.hist()
    df[col].plot.kde()
    plt.xlabel('Variable "{}" Distribution'.format(col))
    plt.show()

# %%
numerical_columns = bnbs.select_dtypes(np.number).columns.tolist()

# %%
from ipywidgets import interact, fixed

# %%
interact(numerical_variable_distribution, 
         col=numerical_columns, df=fixed(bnbs));
# Out:
# A Jupyter Widget

# %%
#Function to make all the categorical data into visual representations
def categorical_variable_distributions(col):
    bnbs[col].value_counts(ascending=True,normalize=True).tail(10).plot.barh()
    plt.show()

# %%
categorical_columns = bnbs.select_dtypes(["object","category"]).columns.tolist()

# %%
interact(categorical_variable_distributions,col=categorical_columns);
# Out:
# A Jupyter Widget

# %% [markdown]
# ## Set a group count

# %%
def pivot_count(df, rows, columns, calc_field):
    df_pivot = df.pivot_table(values=calc_field, 
                              index=rows, 
                              columns=columns, 
                              aggfunc=np.size
                             ).dropna(axis=0, how='all')
    return df_pivot

# %%
#Make a pivot counter on the number of airbnbs there are based on the number of people can stay in each neighborhood
accomodates_by_neighborhood= pivot_count(bnbs, "accommodates","neighborhood", "reviews")
accomodates_by_neighborhood
# Out:
# neighborhood  Ajuda  Alcântara  Alvalade  Areeiro  Arroios  Avenidas Novas  \
# accommodates
# 1               5.0       10.0      48.0     45.0    122.0            64.0
# 2              28.0       72.0      83.0    105.0    645.0           239.0
# 3              12.0       17.0      25.0     18.0    123.0            51.0
# 4              36.0       65.0      49.0     47.0    344.0            85.0
# 5              12.0       13.0      13.0     20.0     97.0            18.0
# 6              10.0       21.0      22.0     15.0    155.0            51.0
# 7               2.0        3.0       4.0      5.0     30.0             9.0
# 8               2.0        6.0       6.0     10.0     56.0            18.0
# 9               NaN        1.0       1.0      5.0     15.0             7.0
# 10              NaN        2.0       2.0      4.0     30.0            11.0
# 11              NaN        1.0       NaN      1.0      4.0             4.0
# 12              1.0        2.0       NaN      4.0     18.0             4.0
# 13              NaN        NaN       NaN      NaN      1.0             NaN
# 14              NaN        NaN       NaN      NaN      8.0             2.0
# 15              NaN        NaN       NaN      NaN      1.0             2.0
# 16              NaN        NaN       NaN      1.0     15.0             1.0
#
# neighborhood  Beato  Belém  Benfica  Campo de Ourique     ...       Marvila  \
# accommodates                                              ...
# 1               2.0    5.0      4.0              13.0     ...           5.0
# 2              50.0   53.0     21.0             103.0     ...          14.0
# 3               5.0   28.0      6.0              39.0     ...           5.0
# 4              21.0   87.0     14.0              92.0     ...          16.0
# 5               2.0   22.0      9.0              23.0     ...           1.0
# 6               2.0   39.0     13.0              27.0     ...           4.0
# 7               1.0    5.0      2.0               6.0     ...           2.0
# 8               1.0    6.0      NaN               4.0     ...           3.0
# 9               NaN    1.0      1.0               1.0     ...           NaN
# 10              NaN    6.0      NaN               9.0     ...           1.0
# 11              NaN    NaN      NaN               NaN     ...           NaN
# 12              NaN    1.0      NaN               NaN     ...           NaN
# 13              NaN    NaN      NaN               NaN     ...           NaN
# 14              NaN    NaN      NaN               1.0     ...           NaN
# 15              NaN    NaN      NaN               NaN     ...           NaN
# 16              NaN    1.0      1.0               1.0     ...           NaN
#
# neighborhood  Misericórdia  Olivais  Parque das Nações  Penha de França  \
# accommodates
# 1                     43.0     11.0                5.0             41.0
# 2                    598.0     40.0               48.0            168.0
# 3                    246.0      8.0               25.0             30.0
# 4                    740.0     25.0               89.0             89.0
# 5                    185.0      7.0               22.0             22.0
# 6                    339.0     13.0               44.0             36.0
# 7                     57.0      1.0                9.0              1.0
# 8                     85.0      1.0                8.0             10.0
# 9                     20.0      NaN                NaN              2.0
# 10                    35.0      1.0                NaN              2.0
# 11                     6.0      1.0                NaN              4.0
# 12                    14.0      NaN                NaN              NaN
# 13                     2.0      NaN                NaN              NaN
# 14                     5.0      NaN                NaN              NaN
# 15                     9.0      NaN                NaN              1.0
# 16                    18.0      NaN                NaN              1.0
#
# neighborhood  Santa Clara  Santa Maria Maior  Santo António  \
# accommodates
# 1                     4.0               60.0           49.0
# 2                     8.0              736.0          317.0
# 3                     4.0              295.0          101.0
# 4                     7.0              930.0          308.0
# 5                     NaN              198.0           66.0
# 6                     NaN              373.0          134.0
# 7                     NaN               58.0           23.0
# 8                     NaN               74.0           44.0
# 9                     NaN               13.0            6.0
# 10                    NaN               26.0           26.0
# 11                    NaN               10.0            4.0
# 12                    NaN               10.0            6.0
# 13                    NaN                1.0            2.0
# 14                    NaN                1.0            4.0
# 15                    NaN                2.0            1.0
# 16                    NaN               11.0           14.0
#
# neighborhood  São Domingos de Benfica  São Vicente
# accommodates
# 1                                11.0         27.0
# 2                                53.0        277.0
# 3                                 8.0         93.0
# 4                                33.0        366.0
# 5                                10.0         74.0
# 6                                11.0        137.0
# 7                                 2.0         20.0
# 8                                 6.0         19.0
# 9                                 1.0          6.0
# 10                                2.0          6.0
# 11                                1.0          NaN
# 12                                NaN          1.0
# 13                                NaN          NaN
# 14                                NaN          1.0
# 15                                NaN          NaN
# 16                                NaN         14.0
#
# [16 rows x 24 columns]

# %%
def heatmap_count_types(df, col1, col2):
    pivot_table = pivot_count(df,col1, col2, "reviews")
    sns.heatmap(pivot_table, annot=True, fmt='g')
    plt.ylabel(col1)
    plt.xlabel(col2)
    plt.show()

# %%
interact(heatmap_count_types, col1=bnbs.columns.drop(["room_id", "host_id", "bedrooms"]),
                                 col2=bnbs.columns.drop(["room_id", "host_id", "bedrooms","price_ratings"]),
                                 df=fixed(bnbs));
# Out:
# A Jupyter Widget

# %% [markdown]
# # Standardization, dealing with missing data

# %%
n_records = len(bnbs)
def missing_values_col(df):
    for column in df:
        print("{} | {} | {}".format(
            column, len(df[df[column].isnull()]) / (1.0*n_records), df[column].dtype
        ))

missing_values_col(bnbs)
# Out:
# room_id | 0.0 | int64
# host_id | 0.0 | int64
# room_type | 0.0 | object
# neighborhood | 0.0 | object
# reviews | 0.0 | int64
# overall_satisfaction | 0.0007557436517533253 | float64
# accommodates | 0.0 | int64
# bedrooms | 0.0 | int64
# price | 0.0 | int64
# relative_reviews | 0.0 | object
# price_ratings | 0.0 | object

# %%
bnbs["overall_satisfaction"] = bnbs.overall_satisfaction.fillna(0.0)
bnbs.shape
# Out:
# (13232, 11)

# %%
bnbs[bnbs.overall_satisfaction==0.0]
# Out:
#         room_id    host_id        room_type             neighborhood  reviews  \
# 1         17031      66015  Entire home/apt                 Alvalade        0
# 10        33348     144484     Private room                   Lumiar        2
# 11        34783     149980     Private room                  Estrela        0
# 20        55116     259744     Private room           Avenidas Novas        1
# 26        72807     378525     Private room                 Alvalade        1
# 37        88282     184400  Entire home/apt            Santo António        1
# 42        90559     184400  Entire home/apt            Santo António        2
# 49       101200     530574     Private room  São Domingos de Benfica        2
# 61       122572     614156     Private room  São Domingos de Benfica        0
# 77       135493     184400  Entire home/apt                  Estrela        0
# 79       137434     671930  Entire home/apt        Parque das Nações        0
# 84       143882     697596  Entire home/apt                 Alvalade        0
# 95       155303     746717  Entire home/apt                    Beato        0
# 104      164397     784164     Private room           Avenidas Novas        0
# 137      196619     144484  Entire home/apt          Penha de França        0
# 151      212915    1097919     Private room                  Benfica        0
# 156      218280     710165     Private room         Campo de Ourique        0
# 158      222942    1157493     Private room                  Arroios        1
# 164      231002    1207800     Private room            Santo António        0
# 175      244494    1282676  Entire home/apt        Santa Maria Maior        2
# 187      262251    1375871     Private room           Avenidas Novas        0
# 202      281407    1466881  Entire home/apt            Santo António        1
# 213      300116    1255219  Entire home/apt                    Beato        0
# 224      305088    3897446  Entire home/apt                  Estrela        1
# 229      311031    1599678  Entire home/apt        Santa Maria Maior        0
# 230      311040    1599678  Entire home/apt        Santa Maria Maior        1
# 238      324570    1660874     Private room            Santo António        0
# 244      335382     604695  Entire home/apt            Santo António        2
# 247      340574    1727918     Private room         Campo de Ourique        0
# 251      343912     604695  Entire home/apt            Santo António        0
# ...         ...        ...              ...                      ...      ...
# 13202  19360001   26864642     Private room                  Arroios        0
# 13203  19361749  127589264  Entire home/apt  São Domingos de Benfica        0
# 13204  19362076   88928860  Entire home/apt          Penha de França        0
# 13205  19362417   28225140     Private room                  Arroios        0
# 13206  19363100   88928860     Private room          Penha de França        0
# 13207  19368183   14317794  Entire home/apt             Misericórdia        0
# 13208  19369538  114388582  Entire home/apt             Misericórdia        0
# 13209  19370050   14317794  Entire home/apt             Misericórdia        0
# 13210  19370165  114388582  Entire home/apt            Santo António        0
# 1      Few have Bnb-ed here             $
# 10     Few have Bnb-ed here             $
# 11     Few have Bnb-ed here             $
# 20     Few have Bnb-ed here             $
# 26     Few have Bnb-ed here             $
# 37     Few have Bnb-ed here             $
# 42     Few have Bnb-ed here             $
# 49     Few have Bnb-ed here             $
# 61     Few have Bnb-ed here             $
# 77     Few have Bnb-ed here             $
# 79     Few have Bnb-ed here             $
# 84     Few have Bnb-ed here           $$$
# 95     Few have Bnb-ed here             $
# 104    Few have Bnb-ed here             $
# 137    Few have Bnb-ed here             $
# 151    Few have Bnb-ed here             $
# 156    Few have Bnb-ed here             $
# 158    Few have Bnb-ed here             $
# 164    Few have Bnb-ed here             $
# 175    Few have Bnb-ed here             $
# 187    Few have Bnb-ed here             $
# 202    Few have Bnb-ed here             $
# 213    Few have Bnb-ed here             $
# 224    Few have Bnb-ed here             $
# 229    Few have Bnb-ed here             $
# 230    Few have Bnb-ed here             $
# 238    Few have Bnb-ed here             $
# 244    Few have Bnb-ed here             $
# 247    Few have Bnb-ed here             $
# 251    Few have Bnb-ed here             $
# ...                     ...           ...
# 13202  Few have Bnb-ed here             $
# 13203  Few have Bnb-ed here             $
# 13204  Few have Bnb-ed here             $
# 13205  Few have Bnb-ed here             $
# 13206  Few have Bnb-ed here             $
# 13207  Few have Bnb-ed here             $
# 13208  Few have Bnb-ed here             $
# 13209  Few have Bnb-ed here             $
# 13210  Few have Bnb-ed here             $
# 13211  Few have Bnb-ed here             $
# 13212  Few have Bnb-ed here             $
# 13213  Few have Bnb-ed here             $
# 13214  Few have Bnb-ed here             $
# 13215  Few have Bnb-ed here             $
# 13216  Few have Bnb-ed here             $
# 13217  Few have Bnb-ed here             $
# 13218  Few have Bnb-ed here             $
# 13219  Few have Bnb-ed here             $
# 13220  Few have Bnb-ed here             $
# 13221  Few have Bnb-ed here             $
# 13222  Few have Bnb-ed here             $
# 13223  Few have Bnb-ed here             $
# 13224  Few have Bnb-ed here             $
# 13225  Few have Bnb-ed here             $
# 13226  Few have Bnb-ed here             $
# 13227  Few have Bnb-ed here            $$
# 13228  Few have Bnb-ed here             $
# 13229  Few have Bnb-ed here             $
# 13230  Few have Bnb-ed here             $
# 13231  Few have Bnb-ed here             $
#
# [3845 rows x 11 columns]

# %%
bnbs.describe()
# Out:
#             room_id       host_id       reviews  overall_satisfaction  \
# count  1.323200e+04  1.323200e+04  13232.000000          13232.000000
# mean   1.055081e+07  3.616444e+07     29.130063              3.282195
# std    6.069884e+06  3.706975e+07     42.802762              2.124352
# min    6.499000e+03  1.445500e+04      0.000000              0.000000
# 25%    5.054848e+06  6.197930e+06      2.000000              0.000000
# 50%    1.166226e+07  2.207571e+07     11.000000              4.500000
# 75%    1.609631e+07  5.546697e+07     39.000000              5.000000
# max    1.940072e+07  1.359156e+08    438.000000              5.000000
#
#        accommodates      bedrooms         price
# count  13232.000000  13232.000000  13232.000000
# mean       3.917775      1.549501     86.592352
# std        2.293757      1.062821    135.208926
# min        1.000000      0.000000     10.000000
# 25%        2.000000      1.000000     45.000000
# 50%        4.000000      1.000000     64.000000
# 75%        5.000000      2.000000     93.000000
# max       16.000000     10.000000   7496.000000

# %%
bnbs.price.plot.kde()
